# %%
import pandas as pd

# %%
import seaborn as sns

# %%
df=pd.read_csv('mental_health.csv')

# %%
df.head(10)
# Out:
#    daily_screen_time_min  num_app_switches  sleep_hours  notification_count  \
# 0                  389.8                53          5.9                  89
# 1                  351.7                52          7.2                  79
# 2                  398.9                39          8.0                 108
# 3                  451.4                44          6.5                  78
# 4                  346.0                43          6.9                  35
# 5                  346.0                38          8.5                 111
# 6                  454.8                40          6.8                  57
# 7                  406.0                57          9.6                  63
# 8                  331.8                42          7.2                  65
# 9                  392.6                63          4.4                 114
#
#    social_media_time_min  focus_score  mood_score  anxiety_level  \
# 0                  133.2          6.8         8.9           10.0
# ...

# %%
df.dropna()
# Out:
#      daily_screen_time_min  num_app_switches  sleep_hours  notification_count  \
# 0                    389.8                53          5.9                  89
# 1                    351.7                52          7.2                  79
# 2                    398.9                39          8.0                 108
# 3                    451.4                44          6.5                  78
# 4                    346.0                43          6.9                  35
# ..                     ...               ...          ...                 ...
# 495                  392.3                58          6.0                 114
# 496                  297.8                56          6.8                  47
# 497                  348.6                42          6.1                  97
# 498                  307.5                33          7.2                  67
# 499                  277.0                41          6.1                  86
#
# ...

# %%
df.shape
# Out:
# (500, 9)

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Length: 500, dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   daily_screen_time_min    500 non-null    float64
#  1   num_app_switches         500 non-null    int64
#  2   sleep_hours              500 non-null    float64
#  3   notification_count       500 non-null    int64
#  4   social_media_time_min    500 non-null    float64
#  5   focus_score              500 non-null    float64
#  6   mood_score               500 non-null    float64
#  7   anxiety_level            500 non-null    float64
#  8   digital_wellbeing_score  500 non-null    float64
# dtypes: float64(7), int64(2)
# memory usage: 35.3 KB

# %%
df.describe()
# Out:
#        daily_screen_time_min  num_app_switches  sleep_hours  \
# count             500.000000        500.000000   500.000000
# mean              360.437800         49.840000     6.557400
# std                58.782476          7.340993     1.192043
# min               180.000000         30.000000     3.000000
# 25%               317.975000         44.000000     5.800000
# 50%               360.800000         50.000000     6.500000
# 75%               398.175000         55.000000     7.325000
# max               591.200000         72.000000    10.000000
#
#        notification_count  social_media_time_min  focus_score  mood_score  \
# count           500.00000             500.000000   500.000000  500.000000
# mean             79.51200             121.771800     6.998000    8.988600
# std              23.97974              43.809443     0.618742    0.519104
# min              20.00000              30.000000     5.500000    7.400000
# ...

# %%
df.isna().sum()
# Out:
# daily_screen_time_min      0
# num_app_switches           0
# sleep_hours                0
# notification_count         0
# social_media_time_min      0
# focus_score                0
# mood_score                 0
# anxiety_level              0
# digital_wellbeing_score    0
# dtype: int64

# %%
df[df.duplicated()==True]
# Out:
# Empty DataFrame
# Columns: [daily_screen_time_min, num_app_switches, sleep_hours, notification_count, social_media_time_min, focus_score, mood_score, anxiety_level, digital_wellbeing_score]
# Index: []

# %%
df.reset_index()
# Out:
#      index  daily_screen_time_min  num_app_switches  sleep_hours  \
# 0        0                  389.8                53          5.9
# 1        1                  351.7                52          7.2
# 2        2                  398.9                39          8.0
# 3        3                  451.4                44          6.5
# 4        4                  346.0                43          6.9
# ..     ...                    ...               ...          ...
# 495    495                  392.3                58          6.0
# 496    496                  297.8                56          6.8
# 497    497                  348.6                42          6.1
# 498    498                  307.5                33          7.2
# 499    499                  277.0                41          6.1
#
#      notification_count  social_media_time_min  focus_score  mood_score  \
# 0                    89                  133.2          6.8         8.9
# ...

# %%
df.dtypes
# Out:
# daily_screen_time_min      float64
# num_app_switches             int64
# sleep_hours                float64
# notification_count           int64
# social_media_time_min      float64
# focus_score                float64
# mood_score                 float64
# anxiety_level              float64
# digital_wellbeing_score    float64
# dtype: object

# %%
df=df.rename(columns={
    'daily_screen_time_min':'min_screen_time',
    'num_app_switches':'app_switches',
    'social_meadia_time_min':'mintime_social_media'
})

# %%
df.head()
# Out:
#    min_screen_time  app_switches  sleep_hours  notification_count  \
# 0            389.8            53          5.9                  89
# 1            351.7            52          7.2                  79
# 2            398.9            39          8.0                 108
# 3            451.4            44          6.5                  78
# 4            346.0            43          6.9                  35
#
#    social_media_time_min  focus_score  mood_score  anxiety_level  \
# 0                  133.2          6.8         8.9           10.0
# 1                  109.5          5.5         9.4           10.0
# 2                   84.7          6.7         9.4            9.4
# 3                   88.9          6.0         9.4            5.1
# 4                   78.8          8.2         9.4            8.0
#
#    digital_wellbeing_score
# 0                     44.8
# 1                     43.6
# 2                     52.6
# 3                     58.4
# 4                     59.7

# %%
df[df['app_switches']<31]
# Out:
#      min_screen_time  app_switches  sleep_hours  notification_count  \
# 257            317.5            30          7.8                  47
#
#      social_media_time_min  focus_score  mood_score  anxiety_level  \
# 257                  166.1          8.5         9.5            7.0
#
#      digital_wellbeing_score
# 257                     66.5

# %%
sns.histplot(df['focus_score'])
# Out:
# <Axes: xlabel='focus_score', ylabel='Count'>

# %%
sns.violinplot(df,x='focus_score',hue='app_switches')
# Out:
# <Axes: xlabel='focus_score'>

# %%
df1=df[df['app_switches']>60]

# %%
df1.head(10)
# Out:
#      min_screen_time  app_switches  sleep_hours  notification_count  \
# 9              392.6            63          4.4                 114
# 25             366.7            64          5.8                  20
# 38             280.3            61          6.8                 103
# 58             379.9            63          6.3                  32
# 74             202.8            62          8.0                  81
# 137            340.7            62          6.6                  22
# 138            408.8            66          7.0                  66
# 144            375.6            65          5.2                  88
# 146            285.8            62          7.0                  95
# 148            391.3            65          3.7                 105
#
#      social_media_time_min  focus_score  mood_score  anxiety_level  \
# 9                    186.9          7.2         7.6           10.0
# 25                   226.4          7.3         8.5            7.2
# ...

# %%
sns.histplot(df1['focus_score'])
# Out:
# <Axes: xlabel='focus_score', ylabel='Count'>

# %%
df1.head(10)
# Out:
#      min_screen_time  app_switches  sleep_hours  notification_count  \
# 9              392.6            63          4.4                 114
# 25             366.7            64          5.8                  20
# 38             280.3            61          6.8                 103
# 58             379.9            63          6.3                  32
# 74             202.8            62          8.0                  81
# 137            340.7            62          6.6                  22
# 138            408.8            66          7.0                  66
# 144            375.6            65          5.2                  88
# 146            285.8            62          7.0                  95
# 148            391.3            65          3.7                 105
#
#      social_media_time_min  focus_score  mood_score  anxiety_level  \
# 9                    186.9          7.2         7.6           10.0
# 25                   226.4          7.3         8.5            7.2
# ...

# %%
df1.shape
# Out:
# (33, 9)

# %%
sns.violinplot(df1,x='min_screen_time',hue='focus_score')
# Out:
# <Axes: xlabel='min_screen_time'>

# %%
sns.violinplot(df1,x='sleep_hours',y='digital_wellbeing_score')
# Out:
# <Axes: xlabel='sleep_hours', ylabel='digital_wellbeing_score'>

# %%
grouped=df.groupby('sleep_hours')['focus_score'].agg(['mean','median','std'])

# %%
print(grouped)
# Out:
#                  mean  median       std
# sleep_hours
# 3.0          7.300000     7.3       NaN
# 3.1          7.300000     7.3       NaN
# 3.3          7.300000     7.3       NaN
# 3.5          7.000000     7.0       NaN
# 3.6          6.800000     6.8       NaN
# ...               ...     ...       ...
# 9.1          7.100000     7.1       NaN
# 9.2          6.700000     6.7       NaN
# 9.6          7.266667     7.3  0.351188
# 9.7          7.800000     7.8       NaN
# 10.0         7.400000     7.4       NaN
#
# [63 rows x 3 columns]

# %%
grouped=df1.groupby('app_switches')['digital_wellbeing_score'].agg(['count','mean','sum'])

# %%
print(grouped)
# Out:
#               count       mean    sum
# app_switches
# 61                2  43.150000   86.3
# 62                8  55.612500  444.9
# 63                4  53.550000  214.2
# 64                2  54.650000  109.3
# 65                6  47.150000  282.9
# 66                3  48.433333  145.3
# 67                1  52.600000   52.6
# 68                1  59.700000   59.7
# 69                2  46.550000   93.1
# 71                2  53.650000  107.3
# 72                2  54.000000  108.0

# %%
grouped=df1.groupby(['sleep_hours','notification_count'])['focus_score'].agg('mean','std')

# %%
print(grouped)
# Out:
# sleep_hours  notification_count
# 3.7          105                   5.9
# 3.9          100                   6.4
# 4.4          114                   7.2
# 4.7          70                    7.1
# 5.2          56                    6.3
#              88                    5.7
# 5.4          83                    7.2
# 5.8          20                    7.3
#              63                    7.1
# 5.9          79                    7.1
# 6.0          20                    7.8
# 6.1          84                    7.6
#              99                    6.0
#              102                   7.4
# 6.2          96                    6.3
# 6.3          32                    7.4
# 6.5          71                    6.8
# 6.6          22                    6.8
#              39                    7.5
#              57                    6.5
#              67                    7.0
#              140                   5.8
# 6.8          103                   6.0
# ...

# %%
pivot=pd.pivot_table(df,index='sleep_hours',columns='app_switches',values='digital_wellbeing_score',aggfunc='count')
#pivot = pd.pivot_table(df, index='sleep_hours', columns='app_switches', values='digital_wellbeing_score', aggfunc='count')

# %%
print(pivot)
# Out:
# app_switches  30  32  33  35   36  37  38  39  40  41  ...  62  63  64  65  \
# sleep_hours                                            ...
# 3.0          NaN NaN NaN NaN  NaN NaN NaN NaN NaN NaN  ... NaN NaN NaN NaN
# 3.1          NaN NaN NaN NaN  NaN NaN NaN NaN NaN NaN  ... NaN NaN NaN NaN
# 3.3          NaN NaN NaN NaN  NaN NaN NaN NaN NaN NaN  ... NaN NaN NaN NaN
# 3.5          NaN NaN NaN NaN  NaN NaN NaN NaN NaN NaN  ... NaN NaN NaN NaN
# 3.6          NaN NaN NaN NaN  NaN NaN NaN NaN NaN NaN  ... NaN NaN NaN NaN
# ...           ..  ..  ..  ..  ...  ..  ..  ..  ..  ..  ...  ..  ..  ..  ..
# 9.1          NaN NaN NaN NaN  NaN NaN NaN NaN NaN NaN  ... NaN NaN NaN NaN
# 9.2          NaN NaN NaN NaN  1.0 NaN NaN NaN NaN NaN  ... NaN NaN NaN NaN
# 9.6          NaN NaN NaN NaN  NaN NaN NaN NaN NaN NaN  ... NaN NaN NaN NaN
# 9.7          NaN NaN NaN NaN  NaN NaN NaN NaN NaN NaN  ... NaN NaN NaN NaN
# 10.0         NaN NaN NaN NaN  NaN NaN NaN NaN NaN NaN  ... NaN NaN NaN NaN
#
# ...

# %%
melted=pd.melt(df,id_vars=['sleep_hours','app_switches'],value_vars='digital_wellbeing_score')

# %%
print(melted)
# Out:
#      sleep_hours  app_switches                 variable  value
# 0            5.9            53  digital_wellbeing_score   44.8
# 1            7.2            52  digital_wellbeing_score   43.6
# 2            8.0            39  digital_wellbeing_score   52.6
# 3            6.5            44  digital_wellbeing_score   58.4
# 4            6.9            43  digital_wellbeing_score   59.7
# ..           ...           ...                      ...    ...
# 495          6.0            58  digital_wellbeing_score   42.4
# 496          6.8            56  digital_wellbeing_score   50.4
# 497          6.1            42  digital_wellbeing_score   49.5
# 498          7.2            33  digital_wellbeing_score   71.6
# 499          6.1            41  digital_wellbeing_score   56.5
#
# [500 rows x 4 columns]

# %%
pivot1=pd.pivot_table(df,index='sleep_hours',columns='app_switches',values='digital_wellbeing_score',aggfunc='count')

# %%
print(pivot1)
# Out:
# app_switches  30  32  33  35   36  37  38  39  40  41  ...  62  63  64  65  \
# sleep_hours                                            ...
# 3.0          NaN NaN NaN NaN  NaN NaN NaN NaN NaN NaN  ... NaN NaN NaN NaN
# 3.1          NaN NaN NaN NaN  NaN NaN NaN NaN NaN NaN  ... NaN NaN NaN NaN
# 3.3          NaN NaN NaN NaN  NaN NaN NaN NaN NaN NaN  ... NaN NaN NaN NaN
# 3.5          NaN NaN NaN NaN  NaN NaN NaN NaN NaN NaN  ... NaN NaN NaN NaN
# 3.6          NaN NaN NaN NaN  NaN NaN NaN NaN NaN NaN  ... NaN NaN NaN NaN
# ...           ..  ..  ..  ..  ...  ..  ..  ..  ..  ..  ...  ..  ..  ..  ..
# 9.1          NaN NaN NaN NaN  NaN NaN NaN NaN NaN NaN  ... NaN NaN NaN NaN
# 9.2          NaN NaN NaN NaN  1.0 NaN NaN NaN NaN NaN  ... NaN NaN NaN NaN
# 9.6          NaN NaN NaN NaN  NaN NaN NaN NaN NaN NaN  ... NaN NaN NaN NaN
# 9.7          NaN NaN NaN NaN  NaN NaN NaN NaN NaN NaN  ... NaN NaN NaN NaN
# 10.0         NaN NaN NaN NaN  NaN NaN NaN NaN NaN NaN  ... NaN NaN NaN NaN
#
# ...

# %%
melted1=pd.melt(df,id_vars=['sleep_hours','app_switches'],value_vars='digital_wellbeing_score')

# %%
pivot2=pd.pivot_table(df1,index='sleep_hours',columns='notification_count',values='focus_score',aggfunc=['mean','std'])

# %%
print(pivot2)
# Out:
#                    mean                                               ...  \
# notification_count  20   22   32   39   40   41   54   56   57   63   ...
# sleep_hours                                                           ...
# 3.7                 NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 3.9                 NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 4.4                 NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 4.7                 NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 5.2                 NaN  NaN  NaN  NaN  NaN  NaN  NaN  6.3  NaN  NaN  ...
# 5.4                 NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 5.8                 7.3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  7.1  ...
# 5.9                 NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 6.0                 7.8  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 6.1                 NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# ...

# %%
#creating a new column sleep_quality
#define the quality_levels
quality_levels={
    'poor':(0,2),
    'fair':(3,4),
    'good':(5,6),
    'excellent':(7,10)
}

#crete a new column 'sleep_quality'
df['sleep_quality']=pd.cut(df['sleep_hours'],bins=[0,4,6,8,10],labels=['poor','fair','good','excellent'])
print(df.head())
# Out:
#    min_screen_time  app_switches  sleep_hours  notification_count  \
# 0            389.8            53          5.9                  89
# 1            351.7            52          7.2                  79
# 2            398.9            39          8.0                 108
# 3            451.4            44          6.5                  78
# 4            346.0            43          6.9                  35
#
#    social_media_time_min  focus_score  mood_score  anxiety_level  \
# 0                  133.2          6.8         8.9           10.0
# 1                  109.5          5.5         9.4           10.0
# 2                   84.7          6.7         9.4            9.4
# 3                   88.9          6.0         9.4            5.1
# 4                   78.8          8.2         9.4            8.0
#
#    digital_wellbeing_score sleep_quality
# 0                     44.8          fair
# 1                     43.6          good
# 2                     52.6          good
# ...

# %%
df1.head()
# Out:
#     min_screen_time  app_switches  sleep_hours  notification_count  \
# 9             392.6            63          4.4                 114
# 25            366.7            64          5.8                  20
# 38            280.3            61          6.8                 103
# 58            379.9            63          6.3                  32
# 74            202.8            62          8.0                  81
#
#     social_media_time_min  focus_score  mood_score  anxiety_level  \
# 9                   186.9          7.2         7.6           10.0
# 25                  226.4          7.3         8.5            7.2
# 38                   95.3          6.0         9.4           10.0
# 58                   71.2          7.4         9.2            1.9
# 74                  127.9          7.9         8.5           10.0
#
#     digital_wellbeing_score sleep_quality
# 9                      41.8          fair
# 25                     54.6          fair
# ...

# %%
print(df1['sleep_hours'].max())
# Out:
# 8.8

# %%
filtered=df[(df['sleep_quality']=='good')&(df['notification_count']>10)]

# %%
print(filtered)
# Out:
#      min_screen_time  app_switches  sleep_hours  notification_count  \
# 1              351.7            52          7.2                  79
# 2              398.9            39          8.0                 108
# 3              451.4            44          6.5                  78
# 4              346.0            43          6.9                  35
# 6              454.8            40          6.8                  57
# ..               ...           ...          ...                 ...
# 494            451.4            56          6.9                 123
# 496            297.8            56          6.8                  47
# 497            348.6            42          6.1                  97
# 498            307.5            33          7.2                  67
# 499            277.0            41          6.1                  86
#
#      social_media_time_min  focus_score  mood_score  anxiety_level  \
# 1                    109.5          5.5         9.4           10.0
# ...

# %%
sorted=df1.sort_values(['sleep_hours','app_switches'],ascending=[False,True])

# %%
print(sorted)
# Out:
#      min_screen_time  app_switches  sleep_hours  notification_count  \
# 354            358.9            67          8.8                 106
# 405            397.4            63          8.6                  95
# 451            417.3            68          8.4                  54
# 74             202.8            62          8.0                  81
# 239            411.1            62          7.9                 118
# 213            399.1            69          7.9                  93
# 297            378.4            71          7.9                  40
# 416            453.1            62          7.5                  41
# 146            285.8            62          7.0                  95
# 138            408.8            66          7.0                  66
# 38             280.3            61          6.8                 103
# 137            340.7            62          6.6                  22
# 493            308.3            62          6.6                  39
# ...

# %%
sorted=df1.sort_values(['sleep_quality','notification_count'],ascending=[True,False])

# %%
print(sorted)
# Out:
#      min_screen_time  app_switches  sleep_hours  notification_count  \
# 148            391.3            65          3.7                 105
# 370            361.5            66          3.9                 100
# 9              392.6            63          4.4                 114
# 144            375.6            65          5.2                  88
# 227            295.3            66          5.4                  83
# 486            321.2            63          5.9                  79
# 489            412.9            65          4.7                  70
# 326            429.5            65          5.8                  63
# 291            330.4            72          5.2                  56
# 25             366.7            64          5.8                  20
# 172            355.4            65          6.0                  20
# 174            376.6            65          6.6                 140
# 239            411.1            62          7.9                 118
# ...

# %%
sorted=df1.sort_values(['focus_score','digital_wellbeing_score'],ascending=[True,False])

# %%
print(sorted)
# Out:
#      min_screen_time  app_switches  sleep_hours  notification_count  \
# 144            375.6            65          5.2                  88
# 174            376.6            65          6.6                 140
# 416            453.1            62          7.5                  41
# 148            391.3            65          3.7                 105
# 38             280.3            61          6.8                 103
# 285            242.9            61          6.1                  99
# 405            397.4            63          8.6                  95
# 291            330.4            72          5.2                  56
# 368            365.9            69          6.2                  96
# 370            361.5            66          3.9                 100
# 160            301.5            64          6.6                  57
# 213            399.1            69          7.9                  93
# 354            358.9            67          8.8                 106
# ...
